# %% [markdown]
# <a href="https://colab.research.google.com/github/YilmazGo/ASSIGNMENT/blob/main/Statistics_Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Descriptive Statistics

# %% [markdown]
#  Import **NumPy**, **SciPy**, and **Pandas**

# %%
import numpy as np
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
#  Randomly generate 1,000 samples from the normal distribution using `np.random.normal()`(mean = 100, standard deviation = 15)

# %%
samples = np.random.normal(100,15,1000)
samples
# Out:
# array([ 93.04575389, 123.85625672, 117.39161231,  97.62849151,
#        111.3763593 , 100.88072709,  93.32741044,  87.99008093,
#         81.12446496,  98.72688397, 135.43390836,  84.61500421,
#        119.90103806,  91.34177434,  88.15929215, 105.38867902,
#        105.70690499, 104.79075746,  91.32670452,  86.56718392,
#         83.31518192,  93.82415514,  79.69937496,  86.5560701 ,
#        110.62425527,  95.77721528, 101.07470202, 117.31421182,
#        111.58611629,  80.5851156 ,  85.57999601,  90.82556128,
#         89.47364252,  75.89247611,  99.47144309,  57.30160578,
#         66.66885345, 113.61304333, 101.90354861, 111.01338546,
#         88.51866038, 104.15707523, 122.80644158,  79.39594933,
#         99.92240933,  90.10682304, 118.26454739, 101.10198659,
#        111.78840259,  80.13460413,  93.8760615 , 107.16728595,
#        114.76856895, 121.04699489, 132.24686522,  97.39534404,
#        103.36930462, 136.70070706, 119.16001275,  97.03165564,
# ...

# %% [markdown]
# Compute the **mean**, **median**, and **mode**

# %%
mean = np.mean(samples)
median = np.median (samples)
mode = stats.mode (samples)
print("mean:",mean)
print("median:",median)
print("mode:",mode)
# Out:
# mean: 99.71583548154562
# median: 99.57457331579343
# mode: ModeResult(mode=array([49.39555139]), count=array([1]))

# %% [markdown]
# Compute the **min**, **max**, **Q1**, **Q3**, and **interquartile range**

# %%
min = np.min(samples)
max = np.max(samples)
q1 = np.percentile(samples,25)
q3 = np.percentile(samples,75)
iqr = q3-q1
iqr1 = stats.iqr(samples)
print ("Q1:",q1)
print ("Q3:",q3)
print ("IQR:",iqr)
print ("IQR1:",iqr1)
# Out:
# Q1: 89.17544742314399
# Q3: 109.76963954559059
# IQR: 20.5941921224466
# IQR1: 20.5941921224466

# %% [markdown]
# Compute the **variance** and **standard deviation**

# %%
variance = 
std_dev =

# %% [markdown]
# Compute the **skewness** and **kurtosis**

# %%
skewness =
kurtosis =

# %% [markdown]
# ## NumPy Correlation Calculation

# %% [markdown]
# Create an array x of integers between 10 (inclusive) and 20 (exclusive). Use `np.arange()`

# %%
x =

# %% [markdown]
# Then use `np.array()` to create a second array y containing 10 arbitrary integers.

# %%
y =

# %% [markdown]
# Once you have two arrays of the same length, you can compute the **correlation coefficient** between x and y

# %%
r =

# %% [markdown]
# ## Pandas Correlation Calculation

# %% [markdown]
# Run the code below

# %%
x = pd.Series(range(10, 20))
y = pd.Series([2, 1, 4, 5, 8, 12, 18, 25, 96, 48])

# %% [markdown]
# Call the relevant method  to calculate Pearson's r correlation.

# %%
r =

# %% [markdown]
# OPTIONAL. Call the relevant method to calculate Spearman's rho correlation.

# %%
rho =

# %% [markdown]
# ## Seaborn Dataset Tips

# %% [markdown]
# Import Seaborn Library

# %%
import

# %% [markdown]
# Load "tips" dataset from Seaborn

# %%
tips = sns.load_dataset("tips")

# %% [markdown]
# Generate descriptive statistics include those that summarize the central tendency, dispersion

# %% [markdown]
# Call the relevant method to calculate pairwise Pearson's r correlation of columns
